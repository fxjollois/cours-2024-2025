# %% [markdown]
# # Introduction à MongoDB - *évaluation*
#
#
# ## Restaurants

# %%
import pymongo
import pandas

client = pymongo.MongoClient()
db = client.test

# %% [markdown]
# ### Lister tous les restaurants de la chaîne "Bareburger" (rue, quartier)

# %%
pandas.DataFrame(db.restaurants.find(
    { "name": "Bareburger" },
    { "_id": 0, "borough": 1, "address.street": 1 }
))
# Out:
#                            address    borough
# 0          {'street': '31 Avenue'}     Queens
# 1    {'street': 'Laguardia Place'}  Manhattan
# 2           {'street': '7 Avenue'}   Brooklyn
# 3          {'street': '31 Street'}     Queens
# 4           {'street': '8 Avenue'}  Manhattan
# 5           {'street': '2 Avenue'}  Manhattan
# 6      {'street': 'Austin Street'}     Queens
# 7     {'street': 'Bell Boulevard'}     Queens
# 8           {'street': 'Court St'}   Brooklyn
# 9   {'street': 'West   46 Street'}  Manhattan
# 10          {'street': '1 Avenue'}  Manhattan
# 11        {'street': 'William St'}  Manhattan

# %% [markdown]
# ### Lister les trois chaînes de restaurant les plus présentes

# %%
pandas.DataFrame(db.restaurants.aggregate([
    { "$sortByCount": "$name" },
    { "$limit": 3 }
]))
# Out:
#                 _id  count
# 0            Subway    421
# 1  Starbucks Coffee    223
# 2        Mcdonald'S    208

# %% [markdown]
# ### Donner les 10 styles de cuisine les plus présents dans la collection

# %%
pandas.DataFrame(db.restaurants.aggregate([
    { "$sortByCount": "$cuisine" },
    { "$limit": 10 }
]))
# Out:
#                                                  _id  count
# 0                                          American    6183
# 1                                            Chinese   2418
# 2                                    Café/Coffee/Tea   1214
# 3                                              Pizza   1163
# 4                                            Italian   1069
# 5                                              Other   1011
# 6  Latin (Cuban, Dominican, Puerto Rican, South &...    850
# 7                                           Japanese    760
# 8                                            Mexican    754
# 9                                             Bakery    691

# %% [markdown]
# ### Lister les 10 restaurants les moins bien notés (note moyenne la plus haute)

# %%
pandas.DataFrame(db.restaurants.aggregate([
    { "$unwind": "$grades" },
    { "$group": {
        "_id": { "name": "$name", "id": "restaurant_id" },
        "score": { "$avg": "$grades.score" }
    }},
    { "$sort": { "score": -1 }},
    { "$limit": 10 }
]))
# Out:
#                                                  _id  score
# 0  {'name': 'Juice It Health Bar', 'id': 'restaur...   75.0
# 1  {'name': 'Golden Dragon Cuisine', 'id': 'resta...   73.0
# 2  {'name': 'Palombo Pastry Shop', 'id': 'restaur...   69.0
# 3  {'name': 'Chelsea'S Juice Factory', 'id': 'res...   69.0
# 4           {'name': 'Koyla', 'id': 'restaurant_id'}   61.0
# 5  {'name': 'K & D Internet Inc', 'id': 'restaura...   61.0
# 6  {'name': 'Ivory D O S  Inc', 'id': 'restaurant...   60.0
# 7  {'name': 'Ab Halal Restaurant', 'id': 'restaur...   58.0
# 8          {'name': 'Espace', 'id': 'restaurant_id'}   56.0
# 9  {'name': 'Kikka At Whole Foods Chelsea', 'id':...   56.0

# %% [markdown]
# ### Lister par quartier le nombre de restaurants, le score moyen et le pourcentage moyen d'évaluation A

# %%
pandas.DataFrame(db.restaurants.aggregate([
    { "$addFields": { "eval": { "$first": "$grades" }}},
    { "$group": {
        "_id": "$borough",
        "NbRestaurants": { "$sum": 1 },
        "ScoreMoyen": { "$avg": "$eval.score" },
        "NbA": { "$sum": { "$cond": { "if": { "$eq": [ "$eval.grade", "A"]}, "then": 1, "else": 0 }}}
    }},
    { "$addFields": {
        "PctA": { "$multiply": [ { "$divide": [ "$NbA", "$NbRestaurants" ]}, 100]}
    }}
]))
# Out:
#              _id  NbRestaurants  ScoreMoyen   NbA       PctA
# 0        Missing             51    8.520000    50  98.039216
# 1       Brooklyn           6086   10.723014  4957  81.449228
# 2  Staten Island            969   10.773262   785  81.011352
# 3      Manhattan          10259   10.952729  8450  82.366702
# 4          Bronx           2338   10.672095  1926  82.378101
# 5         Queens           5656   11.075630  4519  79.897454

# %% [markdown]
# ### Questions complémentaires
#
# Nécessitent une recherche sur la toile pour compléter ce qu’on a déjà vu dans ce TP.
#
# ### Lister les restaurants (nom et rue uniquement) situés sur une rue ayant le terme “Union” dans le nom

# %%
pandas.DataFrame(db.restaurants.find(
    { "name": {"$regex": "union", "$options": "i" }},
    { "_id": 0, "name": 1, "address.street": 1 }
))
# Out:
#                             address  \
# 0    {'street': 'Henderson Avenue'}
# 1    {'street': 'East   69 Street'}
# 2    {'street': 'East   37 Street'}
# 3        {'street': 'Union Street'}
# 4        {'street': 'Union Avenue'}
# 5      {'street': 'East 17 Street'}
# 6            {'street': '6 Avenue'}
# 7        {'street': 'Union Street'}
# 8             {'street': '44 Road'}
# 9       {'street': 'Corona Avenue'}
# 10           {'street': 'Broadway'}
# 11  {'street': 'Kissena Boulevard'}
# 12  {'street': 'Union Square West'}
# 13   {'street': 'North End Avenue'}
# 14   {'street': 'East   16 Street'}
# 15           {'street': 'Union St'}
# 16       {'street': 'Smith Street'}
# 17    {'street': 'Troutman Street'}
# 18      {'street': 'Ashland Place'}
# 19      {'street': 'Spring Street'}
# 20       {'street': 'Union Avenue'}
# 21           {'street': '6 Avenue'}
#
#                                                  name
# 0                                          Union Hall
# 1                      Union Club Of City Of New York
# 2                               The Union League Club
# 3                               Union Cafe Restaurant
# 4                                          Union Pool
# 5                                Union Square Theater
# 6                           Union Bank Of Switzerland
# 7                                          Union Hall
# 8                           U.N. Federal Credit Union
# 9                                 La Union Restaurant
# 10                      Regal Union Square Stadium 14
# 11              Queens College Student Union Sa Diner
# 12            Union Square Catering Facility Ballroom
# 13                                Union Square Events
# 14                                  Union Square Cafe
# 15                               Union St Pojangmacha
# 16                                      Union Grounds
# 17                                  Union Pizza Works
# 18  Union Square Sports & Entertainment At Theatre...
# 19                                Union Bar & Kitchen
# 20                                           Re.Union
# 21                          Union Bank Of Switzerland

# %% [markdown]
# ### Lister les restaurants ayant eu une visite le 1er février 2014

# %%
from datetime import datetime

pandas.DataFrame(db.restaurants.find(
    { "grades.date": datetime(2014, 2, 1) }
))
# Out:
#                          _id  \
# 0   60006d6aa7aafd5a6d45ce69
# 1   60006d6aa7aafd5a6d45d0ec
# 2   60006d6ba7aafd5a6d45dac1
# 3   60006d6ba7aafd5a6d45dc0d
# 4   60006d6ba7aafd5a6d45e1e3
# 5   60006d6ba7aafd5a6d45e792
# 6   60006d6ba7aafd5a6d45e7a0
# 7   60006d6ca7aafd5a6d45ed39
# 8   60006d6ca7aafd5a6d45f537
# 9   60006d6ca7aafd5a6d45f66d
# 10  60006d6ca7aafd5a6d45ff94
# 11  60006d6da7aafd5a6d46022d
# 12  60006d6da7aafd5a6d46052b
# 13  60006d6da7aafd5a6d46070f
# 14  60006d6da7aafd5a6d460719
# 15  60006d6da7aafd5a6d4609c4
# 16  60006d6da7aafd5a6d460a19
# 17  60006d6da7aafd5a6d460bb3
# 18  60006d6da7aafd5a6d460db9
# 19  60006d6da7aafd5a6d460e0a
# 20  60006d6da7aafd5a6d461030
# 21  60006d6da7aafd5a6d461151
# 22  60006d6da7aafd5a6d4618f9
# 23  60006d6da7aafd5a6d461b6b
#
#                                               address    borough  \
# 0   {'building': '300', 'coord': [-73.8787725, 40....      Bronx
# 1   {'building': '15705', 'coord': [-73.8400791000...     Queens
# 2   {'building': '706', 'coord': [-73.8668038, 40....      Bronx
# 3   {'building': '427', 'coord': [-73.9740765, 40....   Brooklyn
# 4   {'building': '9718', 'coord': [-73.88871520000...   Brooklyn
# 5   {'building': '14908', 'coord': [-73.8153339, 4...     Queens
# 6   {'building': '2087', 'coord': [-73.9615235, 40...   Brooklyn
# 7   {'building': '133-45', 'coord': [-73.832814, 4...     Queens
# 8   {'building': '1050', 'coord': [-73.86184589999...   Brooklyn
# 9   {'building': '300', 'coord': [-73.989723, 40.7...  Manhattan
# 10  {'building': '13620', 'coord': [-73.8290939, 4...     Queens
# 11  {'building': '136-20', 'coord': [-73.8290939, ...     Queens
# 12  {'building': '43-45', 'coord': [-73.825705, 40...     Queens
# 13  {'building': '88-01', 'coord': [-73.8747611, 4...     Queens
# 14  {'building': '2707', 'coord': [-73.98181029999...   Brooklyn
# 15  {'building': '35-64', 'coord': [-73.8724060999...     Queens
# 16  {'building': '5902', 'coord': [-73.9007417, 40...     Queens
# 17  {'building': '81-11', 'coord': [-73.8831919, 4...     Queens
# 18  {'building': '749', 'coord': [-73.864991300000...      Bronx
# 19  {'building': '136-21', 'coord': [-73.828780999...     Queens
# 20  {'building': '13660', 'coord': [-82.4899192, 2...     Queens
# 21  {'building': '13620', 'coord': [-73.8290939, 4...     Queens
# 22  {'building': '4718', 'coord': [-73.8496036, 40...      Bronx
# 23  {'building': '15203', 'coord': [-73.81267, 40....    Missing
#
#                             cuisine  \
# 0                        Hamburgers
# 1    Juice, Smoothies, Fruit Salads
# 2                           Chinese
# 3                             Pizza
# 4                           Chinese
# 5                            Korean
# 6                  Chinese/Japanese
# 7                         American
# 8                         American
# 9                        Hamburgers
# 10                          Chinese
# 11  Ice Cream, Gelato, Yogurt, Ices
# 12                          Chinese
# 13                           Donuts
# 14                          Russian
# 15                          Spanish
# 16                  Café/Coffee/Tea
# 17                        American
# 18                          Spanish
# 19                          Chinese
# 20                           Bakery
# 21                           Korean
# 22                            Other
# 23                          Chicken
#
#                                                grades  \
# 0   [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 1   [{'date': 2015-01-15 00:00:00, 'grade': 'A', '...
# 2   [{'date': 2014-08-11 00:00:00, 'grade': 'A', '...
# 3   [{'date': 2014-07-10 00:00:00, 'grade': 'A', '...
# 4   [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 5   [{'date': 2014-07-23 00:00:00, 'grade': 'B', '...
# 6   [{'date': 2014-07-30 00:00:00, 'grade': 'A', '...
# 7   [{'date': 2014-08-19 00:00:00, 'grade': 'A', '...
# 8   [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 9   [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 10  [{'date': 2014-08-25 00:00:00, 'grade': 'A', '...
# 11  [{'date': 2014-07-29 00:00:00, 'grade': 'B', '...
# 12  [{'date': 2015-01-07 00:00:00, 'grade': 'A', '...
# 13  [{'date': 2015-01-16 00:00:00, 'grade': 'A', '...
# 14  [{'date': 2014-08-19 00:00:00, 'grade': 'A', '...
# 15  [{'date': 2014-08-22 00:00:00, 'grade': 'A', '...
# 16  [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 17  [{'date': 2015-01-12 00:00:00, 'grade': 'A', '...
# 18  [{'date': 2014-02-01 00:00:00, 'grade': 'A', '...
# 19  [{'date': 2015-01-15 00:00:00, 'grade': 'A', '...
# 20  [{'date': 2015-01-07 00:00:00, 'grade': 'Z', '...
# 21  [{'date': 2014-07-24 00:00:00, 'grade': 'A', '...
# 22  [{'date': 2014-09-16 00:00:00, 'grade': 'A', '...
# 23  [{'date': 2014-09-08 00:00:00, 'grade': 'A', '...
#
#                                          name restaurant_id
# 0                                  Mcdonald'S      40395653
# 1                                  Gold'S Gym      40534973
# 2                            K & Q Restaruant      40947971
# 3                             Knapp Pizza Iii      40993361
# 4                 Win Hing Chinese Restaurant      41152860
# 5                    Chinese House Restaurant      41264537
# 6                                        Sake      41265584
# 7                        Roosevelt Sports Bar      41361603
# 8   Forbell Cafe (U.S. Post Office Cafeteria)      41460812
# 9                                 Shake Shack      41474503
# 10                        New Flushing Bakery      41583780
# 11                                Haagen Dazs      41610419
# 12                              First Hot Pot      41631489
# 13                             Dunkin' Donuts      41643866
# 14                         The Lights Of Baku      41644068
# 15                       Emily Bar Restaurant      41664735
# 16                                    Norma'S      41668438
# 17              Dunkin Donuts, Baskin Robbins      41682237
# 18             Una Nueva Esperanza/ Herbalife      41696008
# 19                              Hot Pot House      41697472
# 20                             Cake House Win      41707082
# 21                              Dae Jang Geum      41712232
# 22                      Kennedy Fried Chicken      50002531
# 23                                        Kfc      50004349

# %% [markdown]
# ### Lister les restaurants situés entre les longitudes -74.2 et -74.1 et les lattitudes 40.5 et 40.6

# %%
pandas.DataFrame(db.restaurants.find(
    { 
        "address.coord.0": { "$gte": -74.2, "$lte": -74.1 },
        "address.coord.1": { "$gte":  40.1, "$lte":  40.6 }
    }
))
# Out:
#                           _id  \
# 0    60006d6aa7aafd5a6d45cace
# 1    60006d6aa7aafd5a6d45cad0
# 2    60006d6aa7aafd5a6d45cae5
# 3    60006d6aa7aafd5a6d45cb11
# 4    60006d6aa7aafd5a6d45cb43
# ..                        ...
# 327  60006d6ea7aafd5a6d462cf0
# 328  60006d6ea7aafd5a6d462d14
# 329  60006d6ea7aafd5a6d462d58
# 330  60006d6ea7aafd5a6d462d7f
# 331  60006d6ea7aafd5a6d462d99
#
#                                                address        borough  \
# 0    {'building': '73', 'coord': [-74.1178949, 40.5...  Staten Island
# 1    {'building': '203', 'coord': [-74.152359199999...  Staten Island
# 2    {'building': '37', 'coord': [-74.138263, 40.54...  Staten Island
# 3    {'building': '3823', 'coord': [-74.16536339999...  Staten Island
# 4    {'building': '135', 'coord': [-74.104655999999...  Staten Island
# ..                                                 ...            ...
# 327  {'building': '14', 'coord': [-74.150459, 40.55...  Staten Island
# 328  {'building': '2224', 'coord': [-74.1033838, 40...  Staten Island
# 329  {'building': '365', 'coord': [-74.1102822, 40....  Staten Island
# 330  {'building': '3237', 'coord': [-74.16969230000...  Staten Island
# 331  {'building': '307', 'coord': [-74.1453806, 40....  Staten Island
#
#           cuisine                                             grades  \
# 0    Delicatessen  [{'date': 2014-11-18 00:00:00, 'grade': 'A', '...
# 1    Delicatessen  [{'date': 2015-01-05 00:00:00, 'grade': 'A', '...
# 2       American   [{'date': 2014-04-22 00:00:00, 'grade': 'A', '...
# 3       American   [{'date': 2014-07-15 00:00:00, 'grade': 'B', '...
# 4       American   [{'date': 2014-07-10 00:00:00, 'grade': 'A', '...
# ..            ...                                                ...
# 327         Other                                                 []
# 328         Other                                                 []
# 329         Other                                                 []
# 330         Other                                                 []
# 331         Other                                                 []
#
#                              name restaurant_id
# 0             Plaza Bagels & Deli      40364286
# 1       B & M Hot Bagel & Grocery      40364299
# 2          Great Kills Yacht Club      40364610
# 3                  Joyce'S Tavern      40365692
# 4    Richmond County Country Club      40366928
# ..                            ...           ...
# 327                Famous Falafel      50018576
# 328                  Ciminna Cafe      50018635
# 329                                    50018782
# 330                  Jimmy John'S      50018887
# 331        Christine'S Restaurant      50018953
#
# [332 rows x 7 columns]

# %% [markdown]
# ## AirBnB
#
# Nous allons travailler sur des données AirBnB. Celles-ci sont stockées sur le serveur Mongo dans la collection `listingsAndReviews` de la base `sample_airbnb`.
#
# > [Aide sur les données](https://docs.atlas.mongodb.com/sample-data/sample-airbnb)
#
# Une fois créée la connexion à la collection dans Python, répondre aux questions suivantes :

# %%
db = client.sample_airbnb

# %% [markdown]
# ### Lister les différentes types de logements possibles cf (`room_type`)

# %%
pandas.DataFrame(db.listingsAndReviews.distinct("room_type"))
# Out:
#                  0
# 0  Entire home/apt
# 1     Private room
# 2      Shared room

# %% [markdown]
# ### Lister les différents équipements possibles cf (`amenities`)

# %%
pandas.DataFrame(db.listingsAndReviews.distinct("amenities"))
# Out:
#                                               0
# 0
# 1                              24-hour check-in
# 2                         Accessible-height bed
# 3                      Accessible-height toilet
# 4                              Air conditioning
# ..                                          ...
# 181                                        Wifi
# 182                               Window guards
# 183                                      toilet
# 184  translation missing: en.hosting_amenity_49
# 185  translation missing: en.hosting_amenity_50
#
# [186 rows x 1 columns]

# %% [markdown]
# ### Donner le nombre de logements

# %%
db.listingsAndReviews.count_documents({})
# Out:
# 5555

# %% [markdown]
# ### Donner le nombre de logements de type "Entire home/apt"

# %%
db.listingsAndReviews.count_documents({ "room_type": "Entire home/apt" })
# Out:
# 3489

# %% [markdown]
# ### Donner le nombre de logements proposant la "TV" et le "Wifi (cf `amenities`)

# %%
db.listingsAndReviews.count_documents({ "amenities": { "$in": [ "TV", "Wifi" ]} })
# Out:
# 5443

# %% [markdown]
# ### Donner le nombre de logements n'ayant eu aucun avis

# %%
db.listingsAndReviews.count_documents({ "reviews": [] })
# Out:
# 1632

# %%
db.listingsAndReviews.count_documents({ "reviews": { "$size": 0 } })
# Out:
# 1632

# %% [markdown]
# ### Lister les informations du logement "10545725" (cf _id)

# %%
pandas.DataFrame(db.listingsAndReviews.find({ "_id": "10545725" }))
# Out:
#         _id                            listing_url  \
# 0  10545725  https://www.airbnb.com/rooms/10545725
#
#                            name  \
# 0  Cozy bedroom Sagrada Familia
#
#                                              summary  \
# 0  Cozy bedroom next to the church Sagrada Famíli...
#
#                                                space  \
# 0  Cozy beroom located three minutes from the Sag...
#
#                                          description  \
# 0  Cozy bedroom next to the church Sagrada Famíli...
#
#                                neighborhood_overview notes  \
# 0  Well located on a calm residential area a few ...
#
#                                              transit access  ...  \
# 0  Metro on the corner 5 stops away from the Ramb...         ...
#
#   monthly_price cleaning_fee extra_people guests_included  \
# 0        1080.0         20.0          0.0               1
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '1929411', 'host_url': 'https://ww...
#
#                                              address  \
# 0  {'street': 'Barcelona, Catalunya, Spain', 'sub...
#
#                                         availability  \
# 0  {'availability_30': 0, 'availability_60': 0, '...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                              reviews
# 0  [{'_id': '62460002', 'date': 2016-02-14 05:00:...
#
# [1 rows x 40 columns]

# %% [markdown]
# ### Lister le nom, la rue et le pays des logements dont le prix est supérieur à 10000

# %%
pandas.DataFrame(db.listingsAndReviews.find(
    { "price": { "$gte": 10000 }},
    { "_id": 0, "name": 1, "address.street": 1, "address.country": 1}
))
# Out:
#                                                 name  \
# 0      Apartamento de luxo em Copacabana - 4 quartos
# 1                                          良德街3号温馨住宅
# 2  İstanbul un kalbi sisli. Center of istanbul sisli
# 3                                      `LM 三個睡房的整间公寓
# 4                       HS1-2人大床房+丰泽､苏宁､百脑汇+女人街+美食中心
# 5               5 PEOPLE ROOM ( 1 TRIP and 1 DOUBLE)
#
#                                              address
# 0  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 1  {'street': 'HK, Hong Kong', 'country': 'Hong K...
# 2  {'street': 'Şişli, İstanbul, Turkey', 'country...
# 3  {'street': 'Hong Kong, Kowloon, Hong Kong', 'c...
# 4  {'street': 'Hong Kong, Kowloon, Hong Kong', 'c...
# 5  {'street': 'Hong Kong, Kowloon, Hong Kong', 'c...

# %% [markdown]
# ### Donner le nombre de logements par type

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$sortByCount": "$room_type" }
]))
# Out:
#                _id  count
# 0  Entire home/apt   3489
# 1     Private room   1983
# 2      Shared room     83

# %% [markdown]
# ### Donner le nombre de logements par pays

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$sortByCount": "$address.country" }
]))
# Out:
#              _id  count
# 0  United States   1222
# 1         Turkey    661
# 2         Canada    649
# 3          Spain    633
# 4      Australia    610
# 5         Brazil    606
# 6      Hong Kong    600
# 7       Portugal    555
# 8          China     19

# %% [markdown]
# ### On veut représenter graphiquement la distribution des prix, il nous faut donc récupérer uniquement les tarifs
#
# Un tarif apparraissant plusieurs fois dans la base doit être présent plusieurs fois dans cette liste

# %%
pandas.DataFrame(db.listingsAndReviews.find({}, { "_id": 0, "price": 1 }))
# Out:
#       price
# 0      80.0
# 1     317.0
# 2     115.0
# 3      40.0
# 4     701.0
# ...     ...
# 5550   58.0
# 5551  501.0
# 5552  101.0
# 5553  227.0
# 5554  220.0
#
# [5555 rows x 1 columns]

# %% [markdown]
# ### Calculer pour chaque type de logements (`room_type`) le prix (`price`)

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$group": { "_id": "$room_type", "price": { "$avg": "$price" }}},
    { "$sort": { "price": -1 }},
    { "$project": { "_id": 0, "type": "$_id", "price": { "$round": [ "$price", 2 ]}}}
]))
# Out:
#               type   price
# 0      Shared room  349.59
# 1  Entire home/apt  314.86
# 2     Private room  212.30

# %% [markdown]
# ### On veut représenter la distribution du nombre d'avis. Il faut donc calculer pour chaque logement le nombre d'avis qu'il a eu (cf `reviews`)

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$project": { "nb_reviews": { "$size": "$reviews" }}}
]))
# Out:
#            _id  nb_reviews
# 0     10006546          51
# 1     10009999           0
# 2      1001265          96
# 3     10021707           1
# 4     10030955           0
# ...        ...         ...
# 5550   9983221         107
# 5551   9985696           0
# 5552   9987200          90
# 5553   9990304          13
# 5554   9993190          15
#
# [5555 rows x 2 columns]

# %% [markdown]
# ### Compter le nombre de logement pour chaque équipement possible

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$unwind": "$amenities" },
    { "$sortByCount": "$amenities" }
]))
# Out:
#                       _id  count
# 0                    Wifi   5303
# 1              Essentials   5048
# 2                 Kitchen   4951
# 3                      TV   4295
# 4                 Hangers   4226
# ..                    ...    ...
# 181                 Kayak      1
# 182  Snorkeling equipment      1
# 183               Toaster      1
# 184         Swimming pool      1
# 185           Fax machine      1
#
# [186 rows x 2 columns]

# %% [markdown]
# ### On souhaite connaître les 10 utilisateurs ayant fait le plus de commentaires

# %%
pandas.DataFrame(db.listingsAndReviews.aggregate([
    { "$unwind": "$reviews" },
    { "$group": {
        "_id": {"nom": "$reviews.reviewer_name", "id": "$reviews.reviewer_id"},
        "nb_reviews": { "$sum": 1 }
    }},
    { "$sort": { "nb_reviews": -1 }},
    { "$limit": 10 }
]))
# Out:
#                                      _id  nb_reviews
# 0    {'nom': 'Filipe', 'id': '20775242'}          24
# 1      {'nom': 'Nick', 'id': '67084875'}          13
# 2        {'nom': 'Uge', 'id': '2961855'}          10
# 3      {'nom': 'Lisa', 'id': '20991911'}           9
# 4    {'nom': 'Thien', 'id': '162027327'}           9
# 5      {'nom': 'Lisa', 'id': '69140895'}           8
# 6      {'nom': 'Todd', 'id': '60816198'}           8
# 7      {'nom': 'Jodi', 'id': '12679057'}           8
# 8      {'nom': 'David', 'id': '1705870'}           8
# 9  {'nom': 'Courtney', 'id': '55241576'}           8
